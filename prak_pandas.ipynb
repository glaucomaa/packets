# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Titanic

# %% [markdown]
# # 3D

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %%
ax=axes3d.Axes3D(plt.figure())
plt.show()
# Out:
# C:\Users\MainA\AppData\Local\Temp/ipykernel_8884/3730936428.py:1: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=axes3d.Axes3D(plt.figure())

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
v1=pd.Series(np.random.normal(0,10,1000),name='v1')
v2=pd.Series(2*v1+np.random.normal(60,15,1000),name='v2')

# %%
from locale import normalizemalize

# %%
plt.figure()
plt.hist((v1,v2),histtype='barstacked',density=True)
#v3=np.concatenate((v1,v2))
#sns.kdeplot(v3,color='black')
#sns.kdeplot(v2,color='orange')
sns.kdeplot(v3,color='b')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot?
# Out:
# Object `sns.jointplot` not found.

# %%
sns.heatmap?

# %%
fig.add_axes?

# %% [markdown]
# # Pandas

# %%
dt=pd.read_csv("C:\\Users\\MainA\\Desktop\\titanic.csv")

# %%
dt.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dt.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dt.iloc[:,1:].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dt.loc[:,"Sex":"Age"].head(5)
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
dt[["Age","Sex"]].head(5)
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
dt.loc[dt['SibSp']+dt['Parch']>0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dt.loc[440:451:2,["Sex","Age"]]
# Out:
#         Sex   Age
# 440  female  45.0
# 442    male  25.0
# 444    male   NaN
# 446  female  13.0
# 448  female   5.0
# 450    male  36.0

# %%
print(len(dt)-len(dt[dt["Survived"]==1]),
      len(dt[dt["Survived"]==1]),
      len(dt[dt["Survived"]==1 & dt["Sex"]=="male"]),
      len(dt[dt["Survived"]==1])-len(dt[dt["Survived"]==1 & dt["Sex"]=="male"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ds_road\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# C:\ds_road\anaconda\lib\site-packages\pandas\core\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\ds_road\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# --> 316                 result = libops.scalar_binop(x, y, op)
#     317             except (
#
# ...

# %%
len(dt.query('Survived==1 and Sex=="male"'))
# Out:
# 109

# %%
dt.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dt.dropna?

# %%
dt.pivot?

# %%
dt.query?

# %%
dt[dt["Embarked"]=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
dt.sort_values("Age").head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
dt.sort_values("Age").head(5)

# %% [markdown]
# # Titanic AGAIN

# %%
dt.query('Survived==1 and Sex=="female"').loc[:,'Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 874    28.0
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# Name: Age, Length: 233, dtype: float64

# %%
data=pd.DataFrame({'females':dt.query('Survived==1 and Sex=="female"').loc[:,'Age'],'males':dt.query('Survived==1 and Sex=="male"').loc[:,'Age']})

# %%
data
# Out:
#      females  males
# 1       38.0    NaN
# 2       26.0    NaN
# 3       35.0    NaN
# 8       27.0    NaN
# 9       14.0    NaN
# ..       ...    ...
# 875     15.0    NaN
# 879     56.0    NaN
# 880     25.0    NaN
# 887     19.0    NaN
# 889      NaN   26.0
#
# [342 rows x 2 columns]

# %%
data.sort_values("females",ascending=True)
# Out:
#      females  males
# 644     0.75    NaN
# 469     0.75    NaN
# 381     1.00    NaN
# 172     1.00    NaN
# 479     2.00    NaN
# ..       ...    ...
# 839      NaN    NaN
# 849      NaN    NaN
# 857      NaN   51.0
# 869      NaN    4.0
# 889      NaN   26.0
#
# [342 rows x 2 columns]

# %%
sns.violinplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.boxenplot?

# %%
sns.boxenplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.catplot?

# %%
sns.catplot(data=data)
