# %% [markdown]
# # visualisation

# %%
import numpy as np
import pandas as pd

# %%
normal_sample=np.random.normal(loc=0.0,scale=1.0,size=10000)
random_sample=np.random.random(size=10000)
gamma_sample=np.random.gamma(2,size=10000)

# %%
df=pd.DataFrame({'normal':normal_sample,'random':random_sample,'gamma':gamma_sample})

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean       0.007471      0.501673      1.974934
# std        1.012317      0.290700      1.393866
# min       -3.683567      0.000094      0.007605
# 25%       -0.685013      0.248573      0.953896
# 50%        0.008298      0.501510      1.637769
# 75%        0.698411      0.756243      2.680973
# max        4.041756      0.999924     11.191824

# %%
import matplotlib.pyplot as plt

# %%
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31564/2296435684.py in <module>
# ----> 1 import seabor
#
# ModuleNotFoundError: No module named 'seabor'

# %%
plt.figure()
#_ = plt.boxplot(df['normal'], whis='range')
_ = plt.boxplot(df['normal'],whis=[0,100])

# %%
plt.boxplot?

# %%
__=plt.boxplot([df["normal"],df['random'],df['gamma']],whis=1.5)

# %% [markdown]
# # ANIME

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\MainA\\Desktop\\anime.csv")

# %%
df.head()
# Out:
#                               Title    Production Episodes       Source  \
# 0                Shingeki no Kyojin    Wit Studio       25        Manga
# 1  Fullmetal Alchemist: Brotherhood         Bones       64        Manga
# 2                  Sword Art Online  A-1 Pictures       25  Light novel
# 3                     One Punch Man      Madhouse       12    Web manga
# 4             Boku no Hero Academia         Bones       13        Manga
#
#                                    Genre                   Airdate  Rating  \
# 0           Action,Drama,Fantasy,Mystery  Apr 7, 2013, 01:58 (JST)    8.52
# 1  Action,Adventure,Comedy,Drama,Fantasy  Apr 5, 2009, 17:00 (JST)    9.16
# 2       Action,Adventure,Fantasy,Romance  Jul 8, 2012, 00:00 (JST)    7.20
# 3      Action,Comedy,Sci-Fi,Supernatural  Oct 5, 2015, 01:05 (JST)    8.52
# 4                          Action,Comedy  Apr 3, 2016, 17:00 (JST)    7.98
#
#       Voters                 Theme
# 0  3,142,121  Military,Super Power
# ...

# %%
df.query('Title.str.startswith("Shingeki")',engine='python')
# Out:
#                                                   Title  Production Episodes  \
# 0                                    Shingeki no Kyojin  Wit Studio       25
# 9                           Shingeki no Kyojin Season 2  Wit Studio       12
# 17                          Shingeki no Kyojin Season 3  Wit Studio       12
# 23                   Shingeki no Kyojin Season 3 Part 2  Wit Studio       10
# 38                 Shingeki no Kyojin: The Final Season       MAPPA       16
# 199                 Shingeki no Kyojin: Kuinaki Sentaku  Wit Studio        2
# 212                              Shingeki no Kyojin OVA  Wit Studio        3
# 215         Shingeki no Kyojin: The Final Season Part 2       MAPPA        ?
# 217                        Shingeki no Bahamut: Genesis       MAPPA       12
# 341                      Shingeki no Kyojin: Lost Girls  Wit Studio        3
# 371                    Shingeki no Bahamut: Virgin Soul       MAPPA       24
# ...

# %%
df.query('"tit" in Title',engine='python')
# Out:
# Empty DataFrame
# Columns: [Title, Production, Episodes, Source, Genre, Airdate, Rating, Voters, Theme]
# Index: []

# %%
s="tititititititan"

# %%
str.find?
# Out:
# Docstring:
# S.find(sub[, start[, end]]) -> int
#
# Return the lowest index in S where substring sub is found,
# such that sub is contained within S[start:end].  Optional
# arguments start and end are interpreted as in slice notation.
#
# Return -1 on failure.
# Type:      method_descriptor

# %%
"titan" in s
# Out:
# True

# %%
type(s)
# Out:
# str

# %%
df.query("Source == 'Original'").dropna().sort_values("Rating").tail(80)
# Out:
#                                    Title Production Episodes    Source  \
# 251                         Afro Samurai      Gonzo        5  Original
# 1472                   Uchuu no Stellvia      Xebec       26  Original
# 820                             s.CRY.ed    Sunrise       26  Original
# 907                           Kemonozume   Madhouse       13  Original
# 574                Garo: Honoo no Kokuin      MAPPA       24  Original
# ...                                  ...        ...      ...       ...
# 59                      Samurai Champloo   Manglobe       26  Original
# 37            Tengen Toppa Gurren Lagann     Gainax       27  Original
# 12       Code Geass: Hangyaku no Lelouch    Sunrise       25  Original
# 31                          Cowboy Bebop    Sunrise       26  Original
# 32    Code Geass: Hangyaku no Lelouch R2    Sunrise       25  Original
#
#                                      Genre                    Airdate  Rating  \
# ...

# %% [markdown]
# ## date distribution

# %%
df.dropna().query("Airdate.str.find('?') ==-1",engine='python')
# Out:
#                                      Title            Production Episodes  \
# 0                       Shingeki no Kyojin            Wit Studio       25
# 1         Fullmetal Alchemist: Brotherhood                 Bones       64
# 2                         Sword Art Online          A-1 Pictures       25
# 3                            One Punch Man              Madhouse       12
# 4                    Boku no Hero Academia                 Bones       13
# ...                                    ...                   ...      ...
# 1982            Kagaku Ninja-tai Gatchaman  Tatsunoko Production      105
# 1984                            Tiger Mask        Toei Animation      105
# 1986  Jinzou Ningen Kikaider The Animation                 Radix       13
# 1989                          Brain Powerd               Sunrise       26
# 1991                      Burn Up Scramble           AIC Spirits       12
#
#            Source                                  Genre  \
# ...

# %%
df_fr_date =df.dropna().query("Airdate.str.find('?') ==-1",engine='python')["Airdate"]

# %%
def remake(str: _):
    print(type(_))
    #return _[_.find(',')+2:_.find(',')+6:1]

# %%
df_fr_date.loc[0][df_fr_date.loc[0].find(',')+2:df_fr_date.loc[0].find(',')+6]
# Out:
# '2013'

# %%
df_fr_date
# Out:
# 0        Apr 7, 2013, 01:58 (JST)
# 1        Apr 5, 2009, 17:00 (JST)
# 2        Jul 8, 2012, 00:00 (JST)
# 3        Oct 5, 2015, 01:05 (JST)
# 4        Apr 3, 2016, 17:00 (JST)
#                   ...
# 1982     Oct 1, 1972, 18:00 (JST)
# 1984                  Oct 2, 1969
# 1986    Oct 16, 2000, 23:25 (JST)
# 1989                  Apr 8, 1998
# 1991                 Jan 12, 2004
# Name: Airdate, Length: 989, dtype: object

# %%
df_fr_date.apply(str.find(','))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31564/3133780917.py in <module>
# ----> 1 df_fr_date.apply(str.find(','))
#
# TypeError: find() takes at least 1 argument (0 given)

# %% [markdown]
# ## rating contribution

# %%
rating=pd.DataFrame({'from 3 to 5':df.query("Rating <5")["Rating"] ,'from 3 to 7':df.query("Rating >=5 and Rating <7")["Rating"],'more than 7':df.query("Rating >=7")["Rating"]})

# %%
sns.violinplot(data=rating)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # number of anime contribution

# %%
type(df[['Production','Episodes']])
# Out:
# pandas.core.frame.DataFrame

# %%
nb=pd.DataFrame(df[['Production','Episodes']])

# %%
nb.query?
# Out:
# Signature: nb.query(expr: 'str', inplace: 'bool' = False, **kwargs)
# Docstring:
# Query the columns of a DataFrame with a boolean expression.
#
# Parameters
# ----------
# expr : str
#     The query string to evaluate.
#
#     You can refer to variables
#     in the environment by prefixing them with an '@' character like
#     ``@a + b``.
#
#     You can refer to column names that are not valid Python variable names
#     by surrounding them in backticks. Thus, column names containing spaces
#     or punctuations (besides underscores) or starting with digits must be
#     surrounded by backticks. (For example, a column named "Area (cm^2)" would
#     be referenced as ```Area (cm^2)```). Column names which are Python keywords
#     (like "list", "for", "import", etc) cannot be used.
#
#     For example, if one of your columns is called ``a a`` and you want
#     to sum it with ``b``, your query should be ```a a` + b``.
#
#     .. versionadded:: 0.25.0
# ...

# %%
nb.head()
# Out:
#      Production Episodes
# 0    Wit Studio       25
# 1         Bones       64
# 2  A-1 Pictures       25
# 3      Madhouse       12
# 4         Bones       13

# %%
nb=nb.replace('-','Other')

# %%
nb.Episodes=pd.DataFrame(nb.Episodes.apply(int))

# %%
nb.sort_values(by="Episodes",axis=0)
# Out:
#           Production  Episodes
# 222         DR Movie         0
# 1224           Other         0
# 1649           Nexus         0
# 1383         Sunrise         0
# 1835  Toei Animation         0
# ...              ...       ...
# 236           Gallop       224
# 146              OLM       276
# 60    Toei Animation       291
# 27    Studio Pierrot       366
# 11    Studio Pierrot       500
#
# [1992 rows x 2 columns]

# %%
nb.sort_values?
# Out:
# Signature:
# nb.sort_values(
#     by,
#     axis: 'Axis' = 0,
#     ascending=True,
#     inplace: 'bool' = False,
#     kind: 'str' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc' = None,
# )
# Docstring:
# Sort by the values along either axis.
#
# Parameters
# ----------
#         by : str or list of str
#             Name or list of names to sort by.
#
#             - if `axis` is 0 or `'index'` then `by` may contain index
#               levels and/or column labels.
#             - if `axis` is 1 or `'columns'` then `by` may contain column
#               levels and/or index labels.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#      Axis to be sorted.
# ascending : bool or list of bool, default True
#      Sort ascending vs. descending. Specify list for multiple sort
#      orders.  If this is a list of bools, must match the length of
#      the by.
# inplace : bool, default False
# ...
